# %% [markdown]
# # Students' Academic Performance Dataset

# %% [markdown]
# - Source: Elaf Abu Amrieh, Thair Hamtini, and Ibrahim Aljarah, The University of Jordan, Amman, Jordan
# - Link: [Link1](http://www.Ibrahimaljarah.com) [Link2](www.ju.edu.jo)

# %% [markdown]
# ## Attributes
#
# - **Gender**: student's gender (nominal: 'Male' or 'Female’)
# - **Nationality**: student's nationality (nominal:’ Kuwait’,’ Lebanon’,’ Egypt’,’ SaudiArabia’,’ USA’,’ Jordan’,’ Venezuela’,’ Iran’,’ Tunis’,’ Morocco’,’ Syria’,’ Palestine’,’ Iraq’,’ Lybia’)
# - **Place of birth**: student's Place of birth (nominal:’ Kuwait’,’ Lebanon’,’ Egypt’,’ SaudiArabia’,’ USA’,’ Jordan’,’ Venezuela’,’ Iran’,’ Tunis’,’ Morocco’,’ Syria’,’ Palestine’,’ Iraq’,’ Lybia’)
# - **Educational Stages**: educational level student belongs (nominal: ‘lowerlevel’,’MiddleSchool’,’HighSchool’)
# - **Grade Levels**: grade student belongs (nominal: ‘G-01’, ‘G-02’, ‘G-03’, ‘G-04’, ‘G-05’, ‘G-06’, ‘G-07’, ‘G-08’, ‘G-09’, ‘G-10’, ‘G-11’, ‘G-12 ‘)
# - **Section ID**: classroom student belongs (nominal:’A’,’B’,’C’)
# - **Topic**: course topic (nominal:’ English’,’ Spanish’, ‘French’,’ Arabic’,’ IT’,’ Math’,’ Chemistry’, ‘Biology’, ‘Science’,’ History’,’ Quran’,’ Geology’)
# - **Semester**: school year semester (nominal:’ First’,’ Second’)
# - **Relation**: Parent responsible for student (nominal:’mom’,’father’)
# - **Raised hand**: how many times the student raises his/her hand on classroom (numeric:0-100)
# - **Visited resources**: how many times the student visits a course content(numeric:0-100)
# - **Viewing announcements**: how many times the student checks the new announcements(numeric:0-100)
# - **Discussion groups**: how many times the student participate on discussion groups (numeric:0-100)
# - **Parent Answering Survey**: parent answered the surveys which are provided from school or not (nominal:’Yes’,’No’)
# - **Parent School Satisfaction**: the Degree of parent satisfaction from school(nominal:’Yes’,’No’)
# - **Student Absence Days**: the number of absence days for each student (nominal: above-7, under-7)

# %% [markdown]
# The students are classified into three numerical intervals based on their total grade/mark: <br>
#
# **Low-Level**: interval includes values from 0 to 69,
#
# **Middle-Level**: interval includes values from 70 to 89,
#
# **High-Level**: interval includes values from 90-100.

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Data

# %%
df = pd.read_csv('xAPI-Edu-Data.csv', sep=',')

# %%
df.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               480 non-null    int64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %%
df.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   480.000000        480.000000         480.000000  480.000000
# mean     46.775000         54.797917          37.918750   43.283333
# std      30.779223         33.080007          26.611244   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      15.750000         20.000000          14.000000   20.000000
# 50%      50.000000         65.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %% [markdown]
# ## EDA - Numerical Variables

# %% [markdown]
# ### Raise hands

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

raise_ = sns.histplot(ax=axes[0], x='raisedhands', data=df, kde=True)
raise_.set_title('Raisehands Distribution')

raise_class = sns.histplot(ax=axes[1], x='raisedhands', hue='Class', data=df, kde=True, hue_order=['L', 'M', 'H'])
raise_class.set_title('Raise hands & Class')

raise_box = sns.boxplot(ax=axes[2], x='raisedhands', data=df)
raise_box.set_title('Box Plot')
# Out:
# Text(0.5, 1.0, 'Box Plot')

# %% [markdown]
# ### Visted Resources

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

visres_ = sns.histplot(ax=axes[0], x='VisITedResources', data=df, kde=True)
visres_.set_title('Visted Resources Distribution')

visres_class = sns.histplot(ax=axes[1], x='VisITedResources', hue='Class', data=df, kde=True, hue_order=['L', 'M', 'H'])
visres_class.set_title('Visited Resources & Class')

visres_box = sns.boxplot(ax=axes[2], x='VisITedResources', data=df)
visres_box.set_title('Box Plot')
# Out:
# Text(0.5, 1.0, 'Box Plot')

# %%
visres_raise_class = sns.jointplot(x='VisITedResources', y='raisedhands', hue='Class', data=df, hue_order=['L', 'M', 'H'], alpha=0.5)

# %% [markdown]
# - Hard to differentiate between Medium and High, but there is a clear differentiation for Low

# %% [markdown]
# ### Announcements View

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

annv_ = sns.histplot(ax=axes[0], x='AnnouncementsView', data=df, kde=True)
annv_.set_title('Announcements View Distribution')

annv_class = sns.histplot(ax=axes[1], x='AnnouncementsView', hue='Class', data=df, kde=True, hue_order=['L', 'M', 'H'])
annv_class.set_title('Announcements View & Class')

annv_box = sns.boxplot(ax=axes[2], x='AnnouncementsView', data=df)
annv_box.set_title('Box Plot')
# Out:
# Text(0.5, 1.0, 'Box Plot')

# %% [markdown]
# ### Discussion

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

disc_ = sns.histplot(ax=axes[0], x='Discussion', data=df, kde=True)
disc_.set_title('Discussion Distribution')

disc_class = sns.histplot(ax=axes[1], x='Discussion', hue='Class', data=df, kde=True, hue_order=['L', 'M', 'H'])
disc_class.set_title('Announcements View & Class')

disc_box = sns.boxplot(ax=axes[2], x='Discussion', data=df)
disc_box.set_title('Box Plot')
# Out:
# Text(0.5, 1.0, 'Box Plot')

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(df, hue='Class', hue_order=['L', 'M', 'H'])

# %% [markdown]
# - Discussion doesn't seem an important variable, because there is no clear differentiation
# - But other variables seem to differentiate different classes quite well
# - Check the correlationship to avoid multicollinearity

# %% [markdown]
# ## EDA - Categorical Variables

# %% [markdown]
# ### Class - Target Variable

# %%
sns.countplot(x='Class', data=df, order=['L', 'M', 'H'])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %% [markdown]
# ### Gender

# %%
sns.countplot(x='gender', hue='Class', data=df, hue_order=['L', 'M', 'H'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# - More number of male students have their low grade than female students
# - Almost similar number of female students have medium grade and high grade
# - Unlike female, there is a large number of gap betwen medium grade and high grade for male students

# %% [markdown]
# ### Nationality

# %%
sns.countplot(x='NationalITy', hue='Class', data=df, hue_order=['L', 'M', 'H'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Kuwait has large number of low grade
# - Jordan, Iraq, Palestine, USA and Lebanon have high number of high grade students

# %% [markdown]
# ### Parent Answering Survey

# %%
sns.countplot(x='ParentAnsweringSurvey', hue='Class', data=df, hue_order=['L', 'M', 'H'])
# Out:
# <AxesSubplot:xlabel='ParentAnsweringSurvey', ylabel='count'>

# %% [markdown]
# - When parents answerd the survey, not many student have low grade
# - On the other hand, the opposite trend is visible when the parents didn't answer the survey
# - This shows that when the parents are interested in their children's grade, these students tend to acheive higher grade than the parents without interest

# %% [markdown]
# ### Parent school Satisfaction

# %%
sns.countplot(x='ParentschoolSatisfaction', hue='Class', data=df, hue_order=['L', 'M', 'H'])
# Out:
# <AxesSubplot:xlabel='ParentschoolSatisfaction', ylabel='count'>

# %% [markdown]
# - The similar trend is occured for parent school satisfaction as the parent answering survey
# - Therefore, this variable can be omitted
# - These parnts maybe satisfied with school because of their good grade

# %% [markdown]
# ### Topic

# %%
sns.countplot(x='Topic', hue='Class', data=df, hue_order=['L', 'M', 'H'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - When the students selected IT, they tend to have a low grade. This implies that IT might be a difficult course to earn high grade
# - Biology students have a high grade
# - For Chemistry, there is a division between low grade and high grade

# %% [markdown]
# ## EDA

# %%
### Mapping class variable
df['Class_value'] = df['Class'].map({'L': -1, 'M': 0, 'H': 1})
df.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %% [markdown]
# ### Gender

# %%
gb_gender = df.groupby('gender').mean()['Class_value']
plt.bar(gb_gender.index, gb_gender)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# - We can clearly see that more male students have lower grade than female students

# %% [markdown]
# ### Topic

# %%
gb_topic = df.groupby('Topic').mean()['Class_value'].sort_values()
plt.barh(gb_topic.index, gb_topic)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# - Previously, it wasn't easy to identify which courses lead students for lower grade
# - This shows that IT, Spanish, IT are difficult courses to acheive high grade
# - Students who selected Biology or Geology get high grade

# %% [markdown]
# ### Student Absence Days

# %%
gb_sad = df.groupby('StudentAbsenceDays').mean()['Class_value'].sort_values(ascending=False)
plt.bar(gb_sad.index, gb_sad)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# - Students under 7 absence days are clearly better than students with above 7 days in terms of grade

# %% [markdown]
# ## Data Preprocessing

# %%
X = pd.get_dummies(df.drop(['ParentschoolSatisfaction', 'Class', 'Class_value'], axis=1), 
                   columns=['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
                                'SectionID', 'Topic', 'Semester', 'Relation', 'ParentAnsweringSurvey', 
                                'StudentAbsenceDays'],
                   drop_first=True)
y = df['Class']

# %% [markdown]
# ## Train/Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model_lr = LogisticRegression(max_iter=10000)
model_lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
from sklearn.metrics import classification_report
pred_lr = model_lr.predict(X_test)
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            H       0.77      0.67      0.72        55
#            L       0.79      0.79      0.79        33
#            M       0.60      0.68      0.64        56
#
#     accuracy                           0.70       144
#    macro avg       0.72      0.71      0.71       144
# weighted avg       0.71      0.70      0.70       144

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBClassifier
model_xgb = XGBClassifier()
model_xgb.fit(X_train, y_train)
# Out:
# [16:26:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=2, num_parallel_tree=1,
#               objective='multi:softprob', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
pred_xgb = model_xgb.predict(X_test)
print(classification_report(y_test, pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            H       0.79      0.69      0.74        55
#            L       0.85      0.85      0.85        33
#            M       0.65      0.73      0.69        56
#
#     accuracy                           0.74       144
#    macro avg       0.76      0.76      0.76       144
# weighted avg       0.75      0.74      0.74       144

# %% [markdown]
# ## LR Coefficient

# %% [markdown]
# ### LR for High Grade

# %%
fig = plt.figure(figsize=(16,8))
plt.bar(X.columns, model_lr.coef_[0,:])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - **StudentAbsenceDays_Under-7, Relation_Mum, ParentAnsweringSurvey_Yes, PlaceofBirth_Saudi, Math** for High Grade

# %% [markdown]
# ### LR for Low Grade

# %%
fig = plt.figure(figsize=(16,8))
plt.bar(X.columns, model_lr.coef_[1,:])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## XGBoost Coefficient

# %% [markdown]
# ### XGBoost for High Grade

# %%
feature_importances_xgb = pd.Series(model_xgb.feature_importances_, index=X.columns)
feature_importances_xgb_sort = feature_importances_xgb.sort_values(ascending=False)[:10]
sns.barplot(x=feature_importances_xgb_sort, y=feature_importances_xgb_sort.index)
# Out:
# <AxesSubplot:>
